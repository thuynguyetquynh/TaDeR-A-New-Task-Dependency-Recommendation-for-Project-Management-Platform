# %% [markdown]
# ### Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import networkx as nx
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import gc
import datetime
import itertools
import re
tf.random.set_seed(123)

import time

# %%
cd /content/drive/MyDrive/AISIA/Jira recommendation/
# Out:
# /content/drive/MyDrive/AISIA/Jira recommendation

# %% [markdown]
# # Load dataset

# %%
def encode_graph(row):
  new_row = []
  for i in row:
    if i==0:
      new_row.append([1,0])
    else:
      new_row.append([0,1])
  return new_row

# %%
def load_project(project_name):
  # Attributes
  df = pd.read_csv('data/{}/attribute_preprocess.csv'.format(project_name))
  df = df.fillna('')
  # Graph
  graph = pd.read_csv('data/{}/graph.csv'.format(project_name), delimiter=',')
  graph = graph.apply(encode_graph)
  graph = graph.values
  return df, graph

# %% [markdown]
# # Get features

# %%
def get_textual_features(df, choose_feature_string):
  # Load title/description/summary vectors
  loading_path = 'embedding/glove/post/{}/'.format(project_name)
  if len(choose_feature_string)!=3:
    for feature in choose_feature_string:
      print('Loading',feature)
      loading_path+=feature+'_'
    loading_path = loading_path[:-1]+'/'
  all_textual_vectors = np.load(loading_path + 'textual_features.npy')
  return all_textual_vectors

# %%
def get_time_features(df):
  createds = pd.to_datetime(df['created'])
  updateds = pd.to_datetime(df['updated'])
  return [createds, updateds]

# %% [markdown]
# # Split data

# %%
def split_data(createds, graph, time_split):
  # Get date to split data
  x = createds[0]
  check_date = x + abs(datetime.timedelta(time_split))

  train_nodes = []
  test_nodes = []

  for i in range(0, len(createds)):
    if createds[i]<=check_date:
      train_nodes.append(i)
    else:
      test_nodes.append(i) 

  # Delete all lonely nodes in test
  c = 0
  new_test_node = []
  for i in test_nodes:
    t = True
    for j in graph[i,:]:
      if j[1]!=0: # has linked
        t = False
    if not t:
      c+=1
      new_test_node.append(i)

  test_nodes = new_test_node
  all_nodes = train_nodes + test_nodes

  return train_nodes, test_nodes, all_nodes

# %% [markdown]
# ### Pairing

# %%
def get_pairs(graph, list_nodes_1, list_nodes_2):
  # Get size
  size_1 = len(list_nodes_1)
  size_2 = len(list_nodes_2)

  # Get index of pairs
  pairs = np.empty((size_1*size_2,2))
  # Get label
  labels = np.empty((size_1*size_2,2))

  c=0
  for i in tqdm(range(0, size_1)):
    for j in range(0, size_2):
      u = list_nodes_1[i]
      v = list_nodes_2[j]
      if u!=v:
        # Get index of pairs
        pairs[c] = [u,v]
        # Get label
        labels[c] = graph[u][v]
        c+=1

  pairs = pairs[:c]
  labels = labels[:c]
  return pairs, labels

# %% [markdown]
# # Get training dataset

# %%
def create_pair_dataset(pairs, labels):
  # Get data
  # Index of pairs which have link
  link_data_index = np.array([i for i in range(len(pairs)) if labels[i][0]==0])

  # Index of pairs which don't have link
  non_link_data_index = np.array([i for i in range(len(pairs)) if labels[i][0]==1])

  return link_data_index, non_link_data_index

def get_separated_data_pairs(input, add_feature = None):
  pairs, labels, createds, updateds = input

  link_data_index, non_link_data_index = create_pair_dataset(pairs, labels)
  
  link_data = []
  non_link_data = []
  print('Get training data pairs')
  # Get link_data
  for index in tqdm(link_data_index):
      p = pairs[index]
      u = int(p[0])
      v = int(p[1])
      link_data.append([u, v])
      
  # Get non_link_data
  for index in tqdm(non_link_data_index):
      p = pairs[index]
      u = int(p[0])
      v = int(p[1])
      non_link_data.append([u, v])
  
  if add_feature != None:
    print('Get time features!')
    link_other_features = []
    non_link_other_features = []
    
    # Get link_data
    for index in tqdm(link_data_index):
        p = pairs[index]
        u = int(p[0])
        v = int(p[1])

        cre_u = createds[u]
        
        if add_feature==1: # Only cre-cre feature
          cre_v = createds[v]
          cre_cre = abs((cre_u - cre_v).days)
          link_other_features.append([cre_cre])
        else:
          if add_feature==2: # Only cre-up feature
            update_v = updateds[v]
            cre_up = abs((cre_u - update_v).days)
            link_other_features.append([cre_up])
          else: # Add all time features (cre_cre, cre_up)
            cre_v = createds[v]
            cre_cre = abs((cre_u - cre_v).days)
            update_v = updateds[v]
            cre_up = abs((cre_u - update_v).days)
            link_other_features.append([cre_cre, cre_up])


    # Get non_link_data
    for index in tqdm(non_link_data_index):
        p = pairs[index]
        u = int(p[0])
        v = int(p[1])
        
        cre_u = createds[u]
        
        if add_feature==1:
          cre_v = createds[v]
          cre_cre = abs((cre_u - cre_v).days)
          non_link_other_features.append([cre_cre])
        else:
          if add_feature==2:
            update_v = updateds[v]
            cre_up = abs((cre_u - update_v).days)
            non_link_other_features.append([cre_up])
          else:
            cre_v = createds[v]
            cre_cre = abs((cre_u - cre_v).days)
            update_v = updateds[v]
            cre_up = abs((cre_u - update_v).days)
            non_link_other_features.append([cre_cre, cre_up])

    return link_data, non_link_data, link_other_features, non_link_other_features
    
  return link_data, non_link_data

# %%
def generate_input(config_generator, train_input):
  batch_size, mul, add_feature = config_generator
  all_textual_vectors, link_data, non_link_data, link_other_features, non_link_other_features = train_input
  while True:
    each_size = int(batch_size/2)
    
    # Shuffle index of link data
    shuffle_index = [index for index in np.random.choice(len(link_data), len(link_data), replace=False)]
    link_data = [link_data[index] for index in shuffle_index]
    
    if add_feature!=None:
      link_other_features = [link_other_features[index] for index in shuffle_index]

    for iter in range(int(len(link_data)/each_size)):
        # Split data by batch size and randomly select non_link_data: 1/2 for link data, 1/2 for unlink data
        
        # Get index
        link_index = np.array(range(iter*each_size, (iter+1)*each_size))
        non_link_index = np.array([index for index in np.random.choice(len(non_link_data), each_size*mul, replace=False)])
        
        link_X = [link_data[i] for i in link_index]
        non_link_X = [non_link_data[i] for i in non_link_index]
        
        # Create X by tokenizing and padding X
        X = np.array(link_X + non_link_X)
        padded_A = all_textual_vectors[X[:,0]]
        padded_B = all_textual_vectors[X[:,1]]

        # Create label y
        link_y = np.vstack([np.zeros(len(link_X)), np.ones(len(link_X))]).T
        non_link_y = np.vstack([np.ones(len(link_X)), np.zeros(len(link_X))]).T
        y = np.concatenate([link_y, non_link_y])
                
        index = np.random.choice(batch_size, batch_size, replace=False)
        if add_feature!=None:
          # Create other features
          link_other_X = np.array([link_other_features[i] for i in link_index])
          non_link_other_X = np.array([non_link_other_features[i] for i in non_link_index])
          other_features = np.concatenate([link_other_X, non_link_other_X])
          yield [padded_A[index], padded_B[index], other_features[index]], y[index]
        else:
          yield [padded_A[index], padded_B[index]], y[index]
  return 0

# %% [markdown]
# ## Model

# %%
def return_model(input_init, add_feature):
  value_maxlen, number_units, lr, l = input_init
  inputs_A = tf.keras.Input(shape=(value_maxlen, 300), name="input_a")
  inputs_B = tf.keras.Input(shape=(value_maxlen, 300), name="input_b")

  if add_feature==1 or add_feature==2:
    inputs_C = tf.keras.Input(shape=(1), name="input_c")
  else:
    inputs_C = tf.keras.Input(shape=(2), name="input_c")

  # Deep Learning model's structure
  cnn_layer = tf.keras.layers.Conv1D(number_units, 3, activation='relu')
  flatten_layer = tf.keras.layers.Flatten(name="flatten")
  dense_1_layer = tf.keras.layers.Dense(number_units, activation="relu", name="dense_1")
  output_layer = tf.keras.layers.Dense(2, activation="softmax", name="dense_output")

  # cnn
  cnn_A = cnn_layer(inputs_A)
  cnn_B = cnn_layer(inputs_B)

  if add_feature==None:
  
    # Concat two embedded inputs
    X = tf.concat([flatten_layer(cnn_A), flatten_layer(cnn_B)], axis=1)
  
    dense_1_X = dense_1_layer(X)
  
    outputs = output_layer(dense_1_X)
  
    model = tf.keras.Model(inputs=[inputs_A, inputs_B], outputs=outputs)
  
  else:
  
    # Concat two embedded inputs
    X = tf.concat([flatten_layer(cnn_A), flatten_layer(cnn_B), inputs_C], axis=1)
  
    dense_1_X = dense_1_layer(X)
  
    outputs = output_layer(dense_1_X)
  
    model = tf.keras.Model(inputs=[inputs_A, inputs_B, inputs_C], outputs=outputs)

  model.compile(tf.keras.optimizers.Adam(learning_rate=lr), loss=l, metrics=["categorical_accuracy"])  
  model.summary()

  return model

# %%
def train_model(model_params, init_input, train_input):
  steps_per_epoch, epochs, batch_size, add_feature = model_params
  model_path, value_maxlen, model, all_textual_vectors = init_input
  links_train, non_links_train, links_other_features_train, non_links_other_features_train = train_input
  
  model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath = model_path, save_best_only=True,save_weights_only=True)
  
  # Config generator
  batch_size = 64
  mul = 3
  config_generator = (batch_size, mul, add_feature)
  train_input = all_textual_vectors, links_train, non_links_train, links_other_features_train, non_links_other_features_train
  history = model.fit(generate_input(config_generator, train_input), 
              steps_per_epoch=steps_per_epoch, 
              epochs=epochs,
              shuffle=False,
              callbacks=[model_checkpoint_callback],
              verbose = 1)
  return history

# %% [markdown]
# ## Recommend

# %%
def model_predict(init_input, data_test, labels_test, other_features):
  value_maxlen, model, all_textual_vectors = init_input
  y_s = np.empty((2,2))
  pred_s = np.empty((2,2))

  each_size = len(data_test) #all dataset
  
  t = 0
  while t<each_size:
    if t+2048 < each_size:
      data_X = data_test[t:t+2048]
    else:
      data_X = data_test[t:]

    X = np.array(data_X)
    padded_A = all_textual_vectors[X[:,0]]
    padded_B = all_textual_vectors[X[:,1]]
    
    # Create label y
    if t+2048 < each_size:
      y = labels_test[t:t+2048]
    else:
      y = labels_test[t:]

    if type(other_features) is np.ndarray:
      # Create features
      if t+2048 < each_size:
        test_features = other_features[t:t+2048]
      else:
        test_features = other_features[t:]
      pred = model.predict([padded_A, padded_B, test_features])
    else:
      pred = model.predict([padded_A, padded_B])
    
    del padded_A
    del padded_B
    gc.collect()
    
    y_s = np.concatenate([y_s, y])
    del y
    gc.collect()
    pred_s = np.concatenate([pred_s, pred])
    del pred
    gc.collect()

    t+=2048

    print(t,'/',each_size)

  # Delete empty value in y_s and pred_s
  y_s = y_s[2:]
  pred_s = pred_s[2:]

  # Get label
  y_s = np.argmax(y_s, axis=1)

  pred_proba = np.array(pred_s)[:,1] # Proba of having link

  pred_s = np.argmax(pred_s, axis=1)

  return y_s, pred_s, pred_proba

# %% [markdown]
# ### Evaluate

# %%
def get_test_data(input, add_feature=None):
    print('Get testing data pairs')
    pairs, labels, createds, updateds = input
    data = []
    test_labels = []
    other_features = []

    # Get link_data_sample
    for index in tqdm(range(len(pairs))):
        p = pairs[index]
        u = int(p[0])
        v = int(p[1])
        data.append([u, v])
        test_labels.append(labels[index])
        if add_feature != None:
          cre_u = createds[u]
          cre_v = createds[v]
          update_v = updateds[v]
          cre_cre = abs((cre_u - cre_v).days)
          cre_up = abs((cre_u - update_v).days)
          if add_feature==1:
            other_features.append([cre_cre])
          else:
            if add_feature==2:
              other_features.append([cre_up])
            else:
              other_features.append([cre_cre, cre_up])
        else:
          other_features = None
    if add_feature!=None:
      other_features = np.array(other_features)
      return data, test_labels, other_features
    else:
      return data, test_labels

# %%
def evaluate(y_s, pred_s):
  m = tf.keras.metrics.Accuracy()
  m.update_state(y_s, pred_s)
  print(m.result().numpy())

  from sklearn.metrics import confusion_matrix, classification_report
  print("Confusion maxtrix")
  print(confusion_matrix(y_s, pred_s))
  print(classification_report(y_s, pred_s, digits= 2))

# %% [markdown]
# ### Recommend

# %%
def recommend_function(createds, test_nodes, test_pairs, pred_proba):
  total_size = len(test_nodes)

  recommend_s = []
  for i in range(total_size):
    recommend_s.append([])

  
  # Make dictionary of test_nodes and position of test_nodes in list
  index_dictionary = dict(zip(test_nodes, range(total_size)))

  print('Make recommends!')
  for iter in tqdm(range(len(test_pairs))):
    pair = test_pairs[iter]
    u = int(pair[0])
    v = int(pair[1])
    if abs((createds[u]-createds[v]).days)<=60:
      proba = pred_proba[iter] 
      if u in index_dictionary.keys():
        index_1 = index_dictionary[u]     
        index_2 = v 
        recommend_s[index_1].append((index_2,proba))
      
      if v in index_dictionary.keys():
        index_1 = index_dictionary[v]     
        index_2 = u
        recommend_s[index_1].append((index_2,proba))

  return recommend_s

# %%
def Acc(pred, gt):
	acc = 0
	for i, item in enumerate(pred):
		if item in gt:
			acc += 1.0 
			break
	return acc

# %%
def MRR(pred, gt):
	mrr = 0
	for i, item in enumerate(pred):
		if item in gt:
			mrr += 1.0/(i+1) 
	return mrr

# %%
def Precision_Recall(pred, gt):
  right = 0
  
  for item in gt:
    if item in pred: # relevant
      right+=1

  if len(pred) == 0:
    precision = 0
  else:
    precision = right/len(pred)
  recall = right/len(gt)
  
  return precision, recall

# %%
def metrics(recommend, label):
  acc = 0
  mrr = 0
  precision = 0
  recall = 0
  for i in range(0, len(recommend)):
    if len(label[i])!=0:
      acc+=Acc(recommend[i], label[i])
      mrr+=MRR(recommend[i], label[i])
      precision_recall = Precision_Recall(recommend[i], label[i])
      precision+=precision_recall[0]
      recall+=precision_recall[1]
  return acc/(len(recommend)), mrr/(len(recommend)), precision/(len(recommend)), recall/(len(recommend))

# %% [markdown]
# ### List of recommend

# %%
def get_result(project_name, path, input):
  createds, test_nodes, all_nodes, test_pairs, pred_proba = input
  recommend_s = recommend_function(createds, test_nodes, test_pairs, pred_proba)
  

  # Sort nodes in pairs
  recommend_s2 = []
  c = 0
  for recommend2 in recommend_s:
    c+=1
    recommend = np.array(sorted(recommend2, key = lambda x: x[1], reverse = True))
    if len(recommend)>0:
      recommend = np.array(recommend[:,0], dtype = int)
    recommend_s2.append(recommend)

  y_test = []

  for i in range(len(test_nodes)):
    nodes = []
    for j in range(len(all_nodes)):
      if graph[test_nodes[i], all_nodes[j]][1] !=0 and graph[test_nodes[i], all_nodes[j]][1] !=0:
        nodes.append(all_nodes[j])
    y_test.append(nodes)
  
  f = open(path, "a")
  

  top = 1
  recommend_s = np.array(recommend_s2)

  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 1:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')


  top = 2
  recommend_s = np.array(recommend_s2)
  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 2:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')

  top = 3
  recommend_s = np.array(recommend_s2)
  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 3:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')


  top = 5
  recommend_s = np.array(recommend_s2)

  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 5:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')


  top = 10
  recommend_s = np.array(recommend_s2)
  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 10:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')

  top = 20
  recommend_s = np.array(recommend_s2)

  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 20:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')

  top = 30
  recommend_s = np.array(recommend_s2)

  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 30:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')

  top = 50
  recommend_s = np.array(recommend_s2)

  recommend_s = [i[:top] for i in recommend_s]

  f.write('Top 50:')
  f.write('\n')
  metric = metrics(recommend_s, y_test)
  f.write('Accuracy = ' + repr(metric[0]))
  f.write('\n')
  f.write('MRR = ' + repr(metric[1]))
  f.write('\n')
  f.write('Recall = ' + repr(metric[3]))
  f.write('\n')
  f.close()

# %% [markdown]
# # Main program

# %% [markdown]
# ### Start

# %%
list_project_names = [('FLUME', 1577, 5, 200, 256)]
list_chosen_textual_features = [['title'], ['description'], ['summary'],
                                ['description', 'title'], ['description', 'summary'],
                                ['description', 'title', 'summary'], ['title', 'summary']]
list_add_features = [1]

# %%
number = -1
for project in list_project_names:
  number+=1
  project_name = project[0]
  time_split = project[1]

  # Model params
  steps_per_epoch = project[2]
  epochs = project[3]
  batch_size = project[4]

  # Load dataset
  df, graph = load_project(project_name)

  # Split data
  createds, updateds = get_time_features(df)
  train_nodes, test_nodes, all_nodes = split_data(createds, graph, time_split)

  # Pairing
  print('Pairing data!')
  train_pairs, train_labels = get_pairs(graph, train_nodes, train_nodes)
  test_pairs, test_labels = get_pairs(graph, test_nodes, all_nodes)

  # Get features

  for textual_features in list_chosen_textual_features:
    all_textual_vectors = get_textual_features(df, textual_features)
    value_maxlen = all_textual_vectors.shape[1]
    for add_feature in list_add_features:
      # Model  
      if add_feature!=None:    
        links_train, non_links_train, link_other_features, non_link_other_features = get_separated_data_pairs([train_pairs, train_labels, createds, updateds], add_feature)
        train_other_features = np.concatenate([link_other_features, non_link_other_features])
        mean = np.mean(train_other_features)
        std = np.std(train_other_features)
        link_other_features = np.array([(link_other_features[i]-mean)/std for i in range(0, len(links_train))])
        non_link_other_features = np.array([(non_link_other_features[i]-mean)/std for i in range(0, len(non_links_train))])
        data_test, labels_test, other_features = get_test_data([test_pairs, test_labels, createds, updateds], add_feature)
        other_features = np.array([(other_features[i]-mean)/std for i in range(0, len(other_features))])
      else:
        links_train, non_links_train = get_separated_data_pairs([train_pairs, train_labels, createds, updateds], add_feature)
        data_test, labels_test = get_test_data([test_pairs, test_labels, createds, updateds], add_feature)

      if add_feature!=None:
        del train_other_features
        gc.collect() 

      result_path = '{}_Test_GloVe_CNN_1_Post.txt'.format(project_name)
      param, lr, l = 256, 1e-3, 'mse'
      f = open(result_path, "a")
      listToStr = ' '.join([str(elem) for elem in textual_features]) 
      listToStr = listToStr + ' ' + repr(add_feature)
      f.write(listToStr)
      f.write('\n')
      if add_feature!=None:
        f.write('\n')
        f.write('mean = ' + repr(mean) + '\n')
        f.write('std = ' + repr(std) + '\n')
      f.close()

      model = return_model([value_maxlen, param, lr, l], add_feature)

      # Train model
      model_path = project_name + '_GloVe_CNN_1_' + str(number) + str(lr) + str(l) + '.h5'
      print('Training model...')
      if add_feature == None:
        history = train_model([steps_per_epoch, epochs, batch_size, add_feature], [model_path, value_maxlen, model, all_textual_vectors], [links_train, non_links_train, None, None])
      else:
        history = train_model([steps_per_epoch, epochs, batch_size, add_feature], [model_path, value_maxlen, model, all_textual_vectors], [links_train, non_links_train, link_other_features, non_link_other_features])

      # summarize history for accuracy
      plt.plot(history.history['categorical_accuracy'])
      plt.title('model accuracy')
      plt.ylabel('accuracy')
      plt.xlabel('epoch')
      plt.legend(['train', 'test'], loc='upper left')
      plt.savefig(project_name + "_GloVe_CNN_1_" + str(number) + str(l) + "_accuracy.png", dpi=1200)

      # summarize history for loss
      plt.plot(history.history['loss'])
      plt.title('model loss')
      plt.ylabel('loss')
      plt.xlabel('epoch')
      plt.legend(['train', 'test'], loc='upper left')
      plt.savefig(project_name + "_GloVe_CNN_1_" + str(number) + str(l) + "_loss.png", dpi=1200)

      # Test model
      if add_feature!=None:
        y_s, pred_s, pred_proba = model_predict([value_maxlen, model, all_textual_vectors], data_test, labels_test, other_features)
      else:
        y_s, pred_s, pred_proba = model_predict([value_maxlen, model, all_textual_vectors], data_test, labels_test, None)
      evaluate(y_s, pred_s)
      get_result(project_name, result_path, [createds, test_nodes, all_nodes, test_pairs, pred_proba])
      np.savez(project_name + '_GloVe_CNN_1_' + str(number) + "y", y_s = y_s, pred_s = pred_s, pred_proba = pred_proba)

      del y_s
      del pred_s
      del model
      gc.collect()
# Out:
# Pairing data!
# 100%|██████████| 2502/2502 [00:19<00:00, 129.66it/s]
# 100%|██████████| 227/227 [00:01<00:00, 118.77it/s]
# Loading title
# Get training data pairs
# 100%|██████████| 1266/1266 [00:00<00:00, 372343.37it/s]
# 100%|██████████| 6256236/6256236 [00:10<00:00, 602155.38it/s]
# Get time features!
# 100%|██████████| 1266/1266 [00:00<00:00, 28137.16it/s]
# 100%|██████████| 6256236/6256236 [03:35<00:00, 29041.51it/s]
# Get testing data pairs
# 100%|██████████| 619256/619256 [00:32<00:00, 18977.78it/s]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_a (InputLayer)            [(None, 20, 300)]    0
# __________________________________________________________________________________________________
# input_b (InputLayer)            [(None, 20, 300)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 18, 256)      230656      input_a[0][0]
#                                                                  input_b[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4608)         0           conv1d[0][0]
#                                                                  conv1d[1][0]
# __________________________________________________________________________________________________
# input_c (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 9217)         0           flatten[0][0]
#                                                                  flatten[1][0]
#                                                                  input_c[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          2359808     tf.concat[0][0]
# __________________________________________________________________________________________________
# dense_output (Dense)            (None, 2)            514         dense_1[0][0]
# ==================================================================================================
# Total params: 2,590,978
# Trainable params: 2,590,978
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Training model...
# Epoch 1/200
# 5/5 [==============================] - 16s 159ms/step - loss: 0.2995 - categorical_accuracy: 0.5125
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 2/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2450 - categorical_accuracy: 0.6313
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 3/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2326 - categorical_accuracy: 0.6031
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 4/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.2151 - categorical_accuracy: 0.6719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 5/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2071 - categorical_accuracy: 0.7000
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 6/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.1915 - categorical_accuracy: 0.7156
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 7/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.1781 - categorical_accuracy: 0.7281
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 8/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.1824 - categorical_accuracy: 0.7344
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 9/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.1329 - categorical_accuracy: 0.8281
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 10/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.1203 - categorical_accuracy: 0.8594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 11/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.1263 - categorical_accuracy: 0.8406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 12/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.1047 - categorical_accuracy: 0.8500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 13/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.1326 - categorical_accuracy: 0.8313
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 14/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.1095 - categorical_accuracy: 0.8531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 15/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.1362 - categorical_accuracy: 0.8125
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 16/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.1199 - categorical_accuracy: 0.8313
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 17/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0922 - categorical_accuracy: 0.8687
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 18/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0869 - categorical_accuracy: 0.8813
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 19/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0878 - categorical_accuracy: 0.8750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 20/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0862 - categorical_accuracy: 0.8813
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 21/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0960 - categorical_accuracy: 0.8562
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 22/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0942 - categorical_accuracy: 0.8719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 23/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0779 - categorical_accuracy: 0.9031
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 24/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0956 - categorical_accuracy: 0.8656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 25/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0647 - categorical_accuracy: 0.9187
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 26/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0706 - categorical_accuracy: 0.9062
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 27/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0748 - categorical_accuracy: 0.9000
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 28/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0651 - categorical_accuracy: 0.9125
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 29/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0788 - categorical_accuracy: 0.8906
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 30/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0834 - categorical_accuracy: 0.8813
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 31/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0751 - categorical_accuracy: 0.9000
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 32/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0646 - categorical_accuracy: 0.9219
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 33/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0654 - categorical_accuracy: 0.9125
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 34/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0665 - categorical_accuracy: 0.9187
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 35/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0512 - categorical_accuracy: 0.9281
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 36/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0625 - categorical_accuracy: 0.9250
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 37/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0711 - categorical_accuracy: 0.9156
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 38/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0609 - categorical_accuracy: 0.9094
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 39/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0395 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 40/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0591 - categorical_accuracy: 0.9219
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 41/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0477 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 42/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0742 - categorical_accuracy: 0.8969
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 43/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0555 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 44/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0660 - categorical_accuracy: 0.9187
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 45/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0649 - categorical_accuracy: 0.9094
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 46/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0656 - categorical_accuracy: 0.9187
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 47/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0733 - categorical_accuracy: 0.8969
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 48/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0380 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 49/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0591 - categorical_accuracy: 0.9250
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 50/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0522 - categorical_accuracy: 0.9344
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 51/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0740 - categorical_accuracy: 0.9031
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 52/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0349 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 53/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0562 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 54/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0599 - categorical_accuracy: 0.9250
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 55/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0441 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 56/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0505 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 57/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0405 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 58/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0419 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 59/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0534 - categorical_accuracy: 0.9312
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 60/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0461 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 61/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0586 - categorical_accuracy: 0.9281
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 62/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0623 - categorical_accuracy: 0.9125
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 63/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0440 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 64/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0395 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 65/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0408 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 66/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0457 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 67/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0521 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 68/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0526 - categorical_accuracy: 0.9250
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 69/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0435 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 70/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0443 - categorical_accuracy: 0.9344
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 71/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0363 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 72/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0268 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 73/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0350 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 74/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0423 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 75/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0310 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 76/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0384 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 77/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0370 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 78/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0396 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 79/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0294 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 80/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0312 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 81/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0330 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 82/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0337 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 83/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0395 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 84/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0491 - categorical_accuracy: 0.9344
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 85/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0291 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 86/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0458 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 87/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0376 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 88/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0387 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 89/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0431 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 90/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0613 - categorical_accuracy: 0.9281
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 91/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0401 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 92/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0465 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 93/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0376 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 94/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0493 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 95/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0363 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 96/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0418 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 97/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0358 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 98/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0245 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 99/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0329 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 100/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0454 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 101/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0499 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 102/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0362 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 103/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0292 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 104/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0245 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 105/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0241 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 106/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0353 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 107/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0279 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 108/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0376 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 109/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0294 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 110/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0274 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 111/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0357 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 112/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0469 - categorical_accuracy: 0.9375
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 113/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0359 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 114/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0321 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 115/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0506 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 116/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0302 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 117/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0430 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 118/200
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0344 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 119/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0269 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 120/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0328 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 121/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0349 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 122/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0517 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 123/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0246 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 124/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0371 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 125/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0368 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 126/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0333 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 127/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0243 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 128/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0332 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 129/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0316 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 130/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0205 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 131/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0379 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 132/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0361 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 133/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0188 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 134/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0332 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 135/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0259 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 136/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0308 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 137/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0342 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 138/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0333 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 139/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0247 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 140/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0423 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 141/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0272 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 142/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0395 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 143/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0229 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 144/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0297 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 145/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0279 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 146/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0317 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 147/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0433 - categorical_accuracy: 0.9438
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 148/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0226 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 149/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0261 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 150/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0216 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 151/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0241 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 152/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0354 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 153/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0237 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 154/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0303 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 155/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0343 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 156/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0267 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 157/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0244 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 158/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0352 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 159/200
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0187 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 160/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0183 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 161/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0293 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 162/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0404 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 163/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0215 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 164/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0345 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 165/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0378 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 166/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0208 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 167/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0142 - categorical_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 168/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0234 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 169/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0224 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 170/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0285 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 171/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0254 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 172/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0299 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 173/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0196 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 174/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0215 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 175/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0230 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 176/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0245 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 177/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0243 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 178/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0386 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 179/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0428 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 180/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0241 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 181/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0203 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 182/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0254 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 183/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0321 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 184/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0228 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 185/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0135 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 186/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0217 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 187/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0275 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 188/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0191 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 189/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0215 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 190/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0324 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 191/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0232 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 192/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0174 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 193/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0325 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 194/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0292 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 195/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0240 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 196/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0187 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 197/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0338 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 198/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0204 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 199/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0328 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 200/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0319 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2048 / 619256
# 4096 / 619256
# 6144 / 619256
# 8192 / 619256
# 10240 / 619256
# 12288 / 619256
# 14336 / 619256
# 16384 / 619256
# 18432 / 619256
# 20480 / 619256
# 22528 / 619256
# 24576 / 619256
# 26624 / 619256
# 28672 / 619256
# 30720 / 619256
# 32768 / 619256
# 34816 / 619256
# 36864 / 619256
# 38912 / 619256
# 40960 / 619256
# 43008 / 619256
# 45056 / 619256
# 47104 / 619256
# 49152 / 619256
# 51200 / 619256
# 53248 / 619256
# 55296 / 619256
# 57344 / 619256
# 59392 / 619256
# 61440 / 619256
# 63488 / 619256
# 65536 / 619256
# 67584 / 619256
# 69632 / 619256
# 71680 / 619256
# 73728 / 619256
# 75776 / 619256
# 77824 / 619256
# 79872 / 619256
# 81920 / 619256
# 83968 / 619256
# 86016 / 619256
# 88064 / 619256
# 90112 / 619256
# 92160 / 619256
# 94208 / 619256
# 96256 / 619256
# 98304 / 619256
# 100352 / 619256
# 102400 / 619256
# 104448 / 619256
# 106496 / 619256
# 108544 / 619256
# 110592 / 619256
# 112640 / 619256
# 114688 / 619256
# 116736 / 619256
# 118784 / 619256
# 120832 / 619256
# 122880 / 619256
# 124928 / 619256
# 126976 / 619256
# 129024 / 619256
# 131072 / 619256
# 133120 / 619256
# 135168 / 619256
# 137216 / 619256
# 139264 / 619256
# 141312 / 619256
# 143360 / 619256
# 145408 / 619256
# 147456 / 619256
# 149504 / 619256
# 151552 / 619256
# 153600 / 619256
# 155648 / 619256
# 157696 / 619256
# 159744 / 619256
# 161792 / 619256
# 163840 / 619256
# 165888 / 619256
# 167936 / 619256
# 169984 / 619256
# 172032 / 619256
# 174080 / 619256
# 176128 / 619256
# 178176 / 619256
# 180224 / 619256
# 182272 / 619256
# 184320 / 619256
# 186368 / 619256
# 188416 / 619256
# 190464 / 619256
# 192512 / 619256
# 194560 / 619256
# 196608 / 619256
# 198656 / 619256
# 200704 / 619256
# 202752 / 619256
# 204800 / 619256
# 206848 / 619256
# 208896 / 619256
# 210944 / 619256
# 212992 / 619256
# 215040 / 619256
# 217088 / 619256
# 219136 / 619256
# 221184 / 619256
# 223232 / 619256
# 225280 / 619256
# 227328 / 619256
# 229376 / 619256
# 231424 / 619256
# 233472 / 619256
# 235520 / 619256
# 237568 / 619256
# 239616 / 619256
# 241664 / 619256
# 243712 / 619256
# 245760 / 619256
# 247808 / 619256
# 249856 / 619256
# 251904 / 619256
# 253952 / 619256
# 256000 / 619256
# 258048 / 619256
# 260096 / 619256
# 262144 / 619256
# 264192 / 619256
# 266240 / 619256
# 268288 / 619256
# 270336 / 619256
# 272384 / 619256
# 274432 / 619256
# 276480 / 619256
# 278528 / 619256
# 280576 / 619256
# 282624 / 619256
# 284672 / 619256
# 286720 / 619256
# 288768 / 619256
# 290816 / 619256
# 292864 / 619256
# 294912 / 619256
# 296960 / 619256
# 299008 / 619256
# 301056 / 619256
# 303104 / 619256
# 305152 / 619256
# 307200 / 619256
# 309248 / 619256
# 311296 / 619256
# 313344 / 619256
# 315392 / 619256
# 317440 / 619256
# 319488 / 619256
# 321536 / 619256
# 323584 / 619256
# 325632 / 619256
# 327680 / 619256
# 329728 / 619256
# 331776 / 619256
# 333824 / 619256
# 335872 / 619256
# 337920 / 619256
# 339968 / 619256
# 342016 / 619256
# 344064 / 619256
# 346112 / 619256
# 348160 / 619256
# 350208 / 619256
# 352256 / 619256
# 354304 / 619256
# 356352 / 619256
# 358400 / 619256
# 360448 / 619256
# 362496 / 619256
# 364544 / 619256
# 366592 / 619256
# 368640 / 619256
# 370688 / 619256
# 372736 / 619256
# 374784 / 619256
# 376832 / 619256
# 378880 / 619256
# 380928 / 619256
# 382976 / 619256
# 385024 / 619256
# 387072 / 619256
# 389120 / 619256
# 391168 / 619256
# 393216 / 619256
# 395264 / 619256
# 397312 / 619256
# 399360 / 619256
# 401408 / 619256
# 403456 / 619256
# 405504 / 619256
# 407552 / 619256
# 409600 / 619256
# 411648 / 619256
# 413696 / 619256
# 415744 / 619256
# 417792 / 619256
# 419840 / 619256
# 421888 / 619256
# 423936 / 619256
# 425984 / 619256
# 428032 / 619256
# 430080 / 619256
# 432128 / 619256
# 434176 / 619256
# 436224 / 619256
# 438272 / 619256
# 440320 / 619256
# 442368 / 619256
# 444416 / 619256
# 446464 / 619256
# 448512 / 619256
# 450560 / 619256
# 452608 / 619256
# 454656 / 619256
# 456704 / 619256
# 458752 / 619256
# 460800 / 619256
# 462848 / 619256
# 464896 / 619256
# 466944 / 619256
# 468992 / 619256
# 471040 / 619256
# 473088 / 619256
# 475136 / 619256
# 477184 / 619256
# 479232 / 619256
# 481280 / 619256
# 483328 / 619256
# 485376 / 619256
# 487424 / 619256
# 489472 / 619256
# 491520 / 619256
# 493568 / 619256
# 495616 / 619256
# 497664 / 619256
# 499712 / 619256
# 501760 / 619256
# 503808 / 619256
# 505856 / 619256
# 507904 / 619256
# 509952 / 619256
# 512000 / 619256
# 514048 / 619256
# 516096 / 619256
# 518144 / 619256
# 520192 / 619256
# 522240 / 619256
# 524288 / 619256
# 526336 / 619256
# 528384 / 619256
# 530432 / 619256
# 532480 / 619256
# 534528 / 619256
# 536576 / 619256
# 538624 / 619256
# 540672 / 619256
# 542720 / 619256
# 544768 / 619256
# 546816 / 619256
# 548864 / 619256
# 550912 / 619256
# 552960 / 619256
# 555008 / 619256
# 557056 / 619256
# 559104 / 619256
# 561152 / 619256
# 563200 / 619256
# 565248 / 619256
# 567296 / 619256
# 569344 / 619256
# 571392 / 619256
# 573440 / 619256
# 575488 / 619256
# 577536 / 619256
# 579584 / 619256
# 581632 / 619256
# 583680 / 619256
# 585728 / 619256
# 587776 / 619256
# 589824 / 619256
# 591872 / 619256
# 593920 / 619256
# 595968 / 619256
# 598016 / 619256
# 600064 / 619256
# 602112 / 619256
# 604160 / 619256
# 606208 / 619256
# 608256 / 619256
# 610304 / 619256
# 612352 / 619256
# 614400 / 619256
# 616448 / 619256
# 618496 / 619256
# 620544 / 619256
# 0.9956092
# Confusion maxtrix
# [[616443   2463]
#  [   256     94]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    618906
#            1       0.04      0.27      0.06       350
#
#     accuracy                           1.00    619256
#    macro avg       0.52      0.63      0.53    619256
# weighted avg       1.00      1.00      1.00    619256
#
# Make recommends!
# 100%|██████████| 619256/619256 [00:20<00:00, 30133.94it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ...
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0273 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 146/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0358 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 147/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0358 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 148/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0245 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 149/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0243 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 150/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0263 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 151/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0413 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 152/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0335 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 153/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0282 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 154/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0446 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 155/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0224 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 156/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0209 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 157/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0456 - categorical_accuracy: 0.9406
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 158/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0194 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 159/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0424 - categorical_accuracy: 0.9531
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 160/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0248 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 161/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0446 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 162/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0273 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 163/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0302 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 164/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0312 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 165/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0256 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 166/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0358 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 167/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0157 - categorical_accuracy: 0.9875
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 168/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0331 - categorical_accuracy: 0.9563
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 169/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0188 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 170/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0470 - categorical_accuracy: 0.9344
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 171/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0438 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 172/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0296 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 173/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0417 - categorical_accuracy: 0.9469
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 174/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0253 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 175/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0468 - categorical_accuracy: 0.9500
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 176/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0320 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 177/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0341 - categorical_accuracy: 0.9594
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 178/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0190 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 179/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0321 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 180/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0237 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 181/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0265 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 182/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0183 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 183/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0273 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 184/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0242 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 185/200
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0190 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 186/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0248 - categorical_accuracy: 0.9688
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 187/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0191 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 188/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0269 - categorical_accuracy: 0.9625
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 189/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0164 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 190/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0173 - categorical_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 191/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0127 - categorical_accuracy: 0.9875
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 192/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0151 - categorical_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 193/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0308 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 194/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0245 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 195/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0213 - categorical_accuracy: 0.9750
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 196/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0174 - categorical_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 197/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0197 - categorical_accuracy: 0.9781
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 198/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0154 - categorical_accuracy: 0.9875
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 199/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0259 - categorical_accuracy: 0.9656
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 200/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0212 - categorical_accuracy: 0.9719
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2048 / 619256
# 4096 / 619256
# 6144 / 619256
# 8192 / 619256
# 10240 / 619256
# 12288 / 619256
# 14336 / 619256
# 16384 / 619256
# 18432 / 619256
# 20480 / 619256
# 22528 / 619256
# 24576 / 619256
# 26624 / 619256
# 28672 / 619256
# 30720 / 619256
# 32768 / 619256
# 34816 / 619256
# 36864 / 619256
# 38912 / 619256
# 40960 / 619256
# 43008 / 619256
# 45056 / 619256
# 47104 / 619256
# 49152 / 619256
# 51200 / 619256
# 53248 / 619256
# 55296 / 619256
# 57344 / 619256
# 59392 / 619256
# 61440 / 619256
# 63488 / 619256
# 65536 / 619256
# 67584 / 619256
# 69632 / 619256
# 71680 / 619256
# 73728 / 619256
# 75776 / 619256
# 77824 / 619256
# 79872 / 619256
# 81920 / 619256
# 83968 / 619256
# 86016 / 619256
# 88064 / 619256
# 90112 / 619256
# 92160 / 619256
# 94208 / 619256
# 96256 / 619256
# 98304 / 619256
# 100352 / 619256
# 102400 / 619256
# 104448 / 619256
# 106496 / 619256
# 108544 / 619256
# 110592 / 619256
# 112640 / 619256
# 114688 / 619256
# 116736 / 619256
# 118784 / 619256
# 120832 / 619256
# 122880 / 619256
# 124928 / 619256
# 126976 / 619256
# 129024 / 619256
# 131072 / 619256
# 133120 / 619256
# 135168 / 619256
# 137216 / 619256
# 139264 / 619256
# 141312 / 619256
# 143360 / 619256
# 145408 / 619256
# 147456 / 619256
# 149504 / 619256
# 151552 / 619256
# 153600 / 619256
# 155648 / 619256
# 157696 / 619256
# 159744 / 619256
# 161792 / 619256
# 163840 / 619256
# 165888 / 619256
# 167936 / 619256
# 169984 / 619256
# 172032 / 619256
# 174080 / 619256
# 176128 / 619256
# 178176 / 619256
# 180224 / 619256
# 182272 / 619256
# 184320 / 619256
# 186368 / 619256
# 188416 / 619256
# 190464 / 619256
# 192512 / 619256
# 194560 / 619256
# 196608 / 619256
# 198656 / 619256
# 200704 / 619256
# 202752 / 619256
# 204800 / 619256
# 206848 / 619256
# 208896 / 619256
# 210944 / 619256
# 212992 / 619256
# 215040 / 619256
# 217088 / 619256
# 219136 / 619256
# 221184 / 619256
# 223232 / 619256
# 225280 / 619256
# 227328 / 619256
# 229376 / 619256
# 231424 / 619256
# 233472 / 619256
# 235520 / 619256
# 237568 / 619256
# 239616 / 619256
# 241664 / 619256
# 243712 / 619256
# 245760 / 619256
# 247808 / 619256
# 249856 / 619256
# 251904 / 619256
# 253952 / 619256
# 256000 / 619256
# 258048 / 619256
# 260096 / 619256
# 262144 / 619256
# 264192 / 619256
# 266240 / 619256
# 268288 / 619256
# 270336 / 619256
# 272384 / 619256
# 274432 / 619256
# 276480 / 619256
# 278528 / 619256
# 280576 / 619256
# 282624 / 619256
# 284672 / 619256
# 286720 / 619256
# 288768 / 619256
# 290816 / 619256
# 292864 / 619256
# 294912 / 619256
# 296960 / 619256
# 299008 / 619256
# 301056 / 619256
# 303104 / 619256
# 305152 / 619256
# 307200 / 619256
# 309248 / 619256
# 311296 / 619256
# 313344 / 619256
# 315392 / 619256
# 317440 / 619256
# 319488 / 619256
# 321536 / 619256
# 323584 / 619256
# 325632 / 619256
# 327680 / 619256
# 329728 / 619256
# 331776 / 619256
# 333824 / 619256
# 335872 / 619256
# 337920 / 619256
# 339968 / 619256
# 342016 / 619256
# 344064 / 619256
# 346112 / 619256
# 348160 / 619256
# 350208 / 619256
# 352256 / 619256
# 354304 / 619256
# 356352 / 619256
# 358400 / 619256
# 360448 / 619256
# 362496 / 619256
# 364544 / 619256
# 366592 / 619256
# 368640 / 619256
# 370688 / 619256
# 372736 / 619256
# 374784 / 619256
# 376832 / 619256
# 378880 / 619256
# 380928 / 619256
# 382976 / 619256
# 385024 / 619256
# 387072 / 619256
# 389120 / 619256
# 391168 / 619256
# 393216 / 619256
# 395264 / 619256
# 397312 / 619256
# 399360 / 619256
# 401408 / 619256
# 403456 / 619256
# 405504 / 619256
# 407552 / 619256
# 409600 / 619256
# 411648 / 619256
# 413696 / 619256
# 415744 / 619256
# 417792 / 619256
# 419840 / 619256
# 421888 / 619256
# 423936 / 619256
# 425984 / 619256
# 428032 / 619256
# 430080 / 619256
# 432128 / 619256
# 434176 / 619256
# 436224 / 619256
# 438272 / 619256
# 440320 / 619256
# 442368 / 619256
# 444416 / 619256
# 446464 / 619256
# 448512 / 619256
# 450560 / 619256
# 452608 / 619256
# 454656 / 619256
# 456704 / 619256
# 458752 / 619256
# 460800 / 619256
# 462848 / 619256
# 464896 / 619256
# 466944 / 619256
# 468992 / 619256
# 471040 / 619256
# 473088 / 619256
# 475136 / 619256
# 477184 / 619256
# 479232 / 619256
# 481280 / 619256
# 483328 / 619256
# 485376 / 619256
# 487424 / 619256
# 489472 / 619256
# 491520 / 619256
# 493568 / 619256
# 495616 / 619256
# 497664 / 619256
# 499712 / 619256
# 501760 / 619256
# 503808 / 619256
# 505856 / 619256
# 507904 / 619256
# 509952 / 619256
# 512000 / 619256
# 514048 / 619256
# 516096 / 619256
# 518144 / 619256
# 520192 / 619256
# 522240 / 619256
# 524288 / 619256
# 526336 / 619256
# 528384 / 619256
# 530432 / 619256
# 532480 / 619256
# 534528 / 619256
# 536576 / 619256
# 538624 / 619256
# 540672 / 619256
# 542720 / 619256
# 544768 / 619256
# 546816 / 619256
# 548864 / 619256
# 550912 / 619256
# 552960 / 619256
# 555008 / 619256
# 557056 / 619256
# 559104 / 619256
# 561152 / 619256
# 563200 / 619256
# 565248 / 619256
# 567296 / 619256
# 569344 / 619256
# 571392 / 619256
# 573440 / 619256
# 575488 / 619256
# 577536 / 619256
# 579584 / 619256
# 581632 / 619256
# 583680 / 619256
# 585728 / 619256
# 587776 / 619256
# 589824 / 619256
# 591872 / 619256
# 593920 / 619256
# 595968 / 619256
# 598016 / 619256
# 600064 / 619256
# 602112 / 619256
# 604160 / 619256
# 606208 / 619256
# 608256 / 619256
# 610304 / 619256
# 612352 / 619256
# 614400 / 619256
# 616448 / 619256
# 618496 / 619256
# 620544 / 619256
# 0.9955608
# Confusion maxtrix
# [[616455   2451]
#  [   298     52]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    618906
#            1       0.02      0.15      0.04       350
#
#     accuracy                           1.00    619256
#    macro avg       0.51      0.57      0.52    619256
# weighted avg       1.00      1.00      1.00    619256
#
# Make recommends!
# 100%|██████████| 619256/619256 [00:20<00:00, 29990.80it/s]
